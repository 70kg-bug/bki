# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Processing data

# %%
df_X = pd.read_csv('df_imputed.csv')
df_y = pd.read_csv('bq-res.csv')

# %%
df_X.shape, df_y.shape
# Out:
# ((40000, 68), (1048575, 14))

# %%
final_df = df_X[[i for i in df_X.columns if 'final' in i]]
target = df_y.warning[:40000]
final_df['target']=df_y['warning']
print(final_df.shape)
final_df.head()
# Out:
# (40000, 12)
#    spo2_final  fio2_final  flow_rate_final  peep_final  pip_final  \
# 0        97.0        40.0              8.0         5.0       20.0
# 1        97.0       100.0              8.0         5.0       16.0
# 2       100.0       100.0              8.0         5.0       16.0
# 3       100.0        50.0              8.0         5.0       16.0
# 4       100.0        50.0              8.0         5.0       16.0
#
#    respiratory_rate_total_final  minute_volume_final  \
# 0                          14.0                  7.0
# 1                          14.0                  7.4
# 2                          14.0                  7.4
# 3                          14.0                  7.4
# 4                          14.0                  7.4
#
#    tidal_volume_observed_final  etco2_final  inspiratory_ratio_final  \
# 0                        450.0         38.0                      1.0
# 1                        492.0         38.0                      1.0
# ...

# %%
final_df.sort_values(by=['target'], ascending=False, inplace=True)
final_df.head()
# Out:
#        spo2_final  fio2_final  flow_rate_final  peep_final  pip_final  \
# 7535         97.0        40.0             50.9         5.0       22.0
# 13851        95.0        40.0              8.0         0.0       14.0
# 3634         98.0        50.0              8.0         5.0       16.0
# 3           100.0        50.0              8.0         5.0       16.0
# 5429         98.0        50.0              8.0        10.0       24.0
#
#        respiratory_rate_total_final  minute_volume_final  \
# 7535                           20.0                  8.2
# 13851                          24.0                 10.8
# 3634                           30.0                 17.5
# 3                              14.0                  7.4
# 5429                           24.0                 12.3
#
#        tidal_volume_observed_final  etco2_final  inspiratory_ratio_final  \
# 7535                         371.0         42.0                      1.0
# ...

# %%
final_df = final_df.iloc[:(final_df.target == 1).sum()*2]
final_df.shape
# Out:
# (3288, 12)

# %%
X = final_df.drop(columns=['target'])
y = final_df['target']
X.shape, y.shape
# Out:
# ((3288, 11), (3288,))

# %% [markdown]
# #### Scale and dimension reduction

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
pca = PCA(n_components=2)

# %%
X = pca.fit_transform(X)
X = scaler.fit_transform(X)

# %% [markdown]
# #### Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3)
X_train.shape, X_test.shape
# Out:
# ((2301, 2), (987, 2))

# %% [markdown]
# ### Training model

# %% [markdown]
# #### Uncaliberated model (step 1)

# %%
from sklearn.ensemble import GradientBoostingClassifier
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "exponential",
}
clf = GradientBoostingClassifier(**params)

# %%
clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, loss='exponential', max_depth=4,
#                            min_samples_split=5, n_estimators=500)

# %% [markdown]
# #### Calculate logits on test set for training caliberated model (step 2)

# %%
logits = clf.predict_proba(X_test)[:,0]
logits[:5]
# Out:
# array([0.14856996, 0.24767045, 0.13003056, 0.20695334, 0.20216277])

# %% [markdown]
# #### Caliberated model (step 3)

# %%
from sklearn.linear_model import LogisticRegression
calib_lg = LogisticRegression(max_iter=500)

# %%
calib_lg.fit(logits.reshape(-1,1), y_test)
# Out:
# LogisticRegression(max_iter=500)

# %% [markdown]
# ### Calculating caliberated probabilities as target for regressor problem (step 4)

# %%
uncalib_proba = clf.predict_proba(X)[:,0]
calib_proba = calib_lg.predict_proba(uncalib_proba.reshape(-1,1))[:,0]
calib_proba.shape, y.shape
# Out:
# ((3288,), (3288,))

# %% [markdown]
# ### Final regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}
model = GradientBoostingRegressor(**params)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, calib_proba, train_size=0.75, test_size=0.25)

# %%
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=4, min_samples_split=5,
#                           n_estimators=500)

# %%
mse = mean_squared_error(y_test, model.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 0.0041

# %%
plt.plot(sorted(y_train), label='Test data')
plt.plot(sorted(model.predict(X_train)), label='Prediction')
plt.show()
